# %% [markdown]
# # Epilepsy and Tumor Diagnosis Results

# %% [markdown]
# GDNN1, DNN1, DNN3 and GDNN3 loss and accuracy

# %%
import numpy as np
import os
import math

path = os.getcwd()
path 
epiNN5 = np.loadtxt(path + "/../results/epilepsy-5NN.out", delimiter=",")

# dnn1 = np.loadtxt(path + "/../results/DNN1.csv", delimiter=",")
# gdnn3 = np.loadtxt(path + "/../results/GDNN3.csv", delimiter=",")
# dnn3 = np.loadtxt(path + "/../results/DNN3.csv", delimiter=",")

epiNN5[2,:]
# Out:
# array([2.        , 0.40087173, 0.52186891, 0.50012028, 0.49695   ])

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
# %matplotlib inline

figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

plt.plot(epiNN5[:,0],epiNN5[:,1], label="epilepsy")
plt.fill_between(epiNN5[:,0], epiNN5[:,1]+epiNN5[:,2],  epiNN5[:,1]-epiNN5[:,2], alpha=0.4)


# plt.plot(dnn1[:,0],dnn1[:,1], label="DNN1")
# plt.plot(gdnn3[:,0],gdnn3[:,1], label="GDNN3")
# plt.plot(dnn3[:,0],dnn3[:,1], label="DNN3")

plt.title('GDNN vs DNN loss through generations')
plt.xlabel('epochs (600 epochs is a new generation for GDNN)')
plt.ylabel('loss');
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
# %matplotlib inline

figure(num=None, figsize=(8, 4), dpi=80, facecolor='w', edgecolor='k')

plt.plot(gdnn1[:,0],gdnn1[:,2], label="GDNN")
plt.plot(dnn1[:,0],dnn1[:,2], label="DNN")
plt.plot(gdnn3[:,0],gdnn3[:,2], label="GDNN3")
plt.plot(dnn3[:,0],dnn3[:,2], label="DNN3")

plt.title('GDNN vs DNN accuracy through generations')
plt.xlabel('epochs (600 epochs is a new generation for GDNN)')
plt.ylabel('accuracy');
plt.legend()
plt.show()
