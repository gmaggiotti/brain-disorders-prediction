# %% [markdown]
# # Tumor Diagnosis Training Results

# %% [markdown]
# GDNN1, DNN1, DNN3 and GDNN3 loss and accuracy

# %%
import numpy as np
import os
import math

path = os.getcwd()
path 
tumNN5 = np.loadtxt(path + "/../results/tumor-5NN_out.csv", delimiter=",")

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
# %matplotlib inline

figure(num=None, figsize=(8, 4), dpi=80, facecolor='w', edgecolor='k')

plt.plot(tumNN5[:,0],tumNN5[:,1], label="tumor-5NN")
plt.fill_between(tumNN5[:,0], tumNN5[:,1]+tumNN5[:,1]*tumNN5[:,2],  tumNN5[:,1]-tumNN5[:,1]*tumNN5[:,2], alpha=0.4)

plt.grid(True)
plt.title('Tumor training process')
plt.xlabel('epochs')
plt.ylabel('loss');
plt.legend()
plt.show()

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
# %matplotlib inline

figure(num=None, figsize=(8, 4), dpi=80, facecolor='w', edgecolor='k')

plt.plot(tumNN5[:,0],tumNN5[:,3], label="tumor-5NN")
plt.fill_between(tumNN5[:,0], tumNN5[:,3]+tumNN5[:,3]*tumNN5[:,4],  tumNN5[:,3]-tumNN5[:,3]*tumNN5[:,4], alpha=0.4)

plt.grid(True)
plt.title('Tumor performance on the test partition')
plt.xlabel('epochs')
plt.ylabel('accuracy');
plt.legend()
plt.show()
